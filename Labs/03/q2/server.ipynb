# %%
import socket
import threading

server = socket.socket()
server.bind(("localhost", 9997))
server.listen(10)

print(">> Chat server started, waiting for users...")

active_users = []

def client_handler(conn, address):
    print(">> New user joined:", address)
    active_users.append(conn)

    while True:
        try:
            message = conn.recv(1024).decode()

            if not message or message.lower() == "exit":
                print(">> User left:", address)
                active_users.remove(conn)
                conn.close()
                break

            print(f"Message from {address}:", message)

            for user in active_users:
                if user != conn:
                    user.send(f"{address} says: {message}".encode())

        except:
            if conn in active_users:
                active_users.remove(conn)
            conn.close()
            break

while True:
    conn, addr = server.accept()
    threading.Thread(target=client_handler, args=(conn, addr)).start()
# Out:
# >> Chat server started, waiting for users...
# >> New user joined: ('127.0.0.1', 55186)
# >> New user joined: ('127.0.0.1', 56421)
# >> New user joined: ('127.0.0.1', 56424)
# Message from ('127.0.0.1', 56421): hii
# Message from ('127.0.0.1', 55186): heloo
# Message from ('127.0.0.1', 56424): everything good
